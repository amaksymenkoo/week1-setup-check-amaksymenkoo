# %%
YOUR_NAME = "amaksymenkoo"
print(YOUR_NAME)
# Out:
# amaksymenkoo

# %%
import pandas as pd
print("pandas imported")
# Out:
# pandas imported

# %%
import platform
print(platform.python_implementation())
# Out:
# Python

# %%
df = pd.DataFrame({"a": [1, 2]})
df
# Out:
#    a
# 0  1
# 1  2
